# %%
print("This is my first line of code!")
# Out:
# This is my first line of code!

# %% [markdown]
# # Introduction
#
# My name is Dustin Heick, I have been working as an analyst for 6 years in records and information management. In July of last year, I moved back to my home state of Kentucky from San Diego, California. I am excited to learn to use tools outside of Excel to perform analysis and use data to make decisions. I have participated in startup tech events before but this is my first course.
